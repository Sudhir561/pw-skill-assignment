# %%
# 1. write a code for reverse string

# there are many ways to reverse string -

# a) using slicing method

original_string = "Hello, World!"

# Reversed string
reversed_string = original_string[::-1]

print(reversed_string)

# b) using for loop

original_string = "Hello, World!"

reversed_string = ""

for char in original_string:
    reversed_string = char + reversed_string

print(reversed_string)

# c) using reversed() function:

original_string = "Hello, World!"
reversed_string = ''.join(reversed(original_string))

print(reversed_string)

# d) using recursion

def reverse_string(s):
    if len(s) == 0:
        return s
    else:
        return reverse_string(s[1:]) + s[0]

original_string = "Hello, World!"
reversed_string = reverse_string(original_string)

print(reversed_string)

# e) using stack(LIFO) data structure

original_string = "Hello, World!"
stack = list(original_string)
reversed_string = ""

while stack:
    reversed_string += stack.pop()

print(reversed_string)
# Out:
# !dlroW ,olleH
# !dlroW ,olleH
# !dlroW ,olleH
# !dlroW ,olleH
# !dlroW ,olleH

# %%
2. write a code for count number of vowels in string ?

a) using for loops

def count_vowels(s):
    vowels = "aeiouAEIOU"  # Define vowels (both lowercase and uppercase)
    count = 0
    
    for char in s:
        if char in vowels:
            count += 1
    
    return count

# Example usage
string = "Hello, World!"
vowel_count = count_vowels(string)
print(f"Number of vowels in '{string}':", vowel_count)

# b) using list comprehension 

def count_vowels(s):
    vowels = "aeiouAEIOU"
    return sum(1 for char in s if char in vowels)

# Example usage
string = "Hello, World!"
vowel_count = count_vowels(string)
print(f"Number of vowels in '{string}':", vowel_count)

# %%
3.WRITE A CODE TO CHECK GIVEN STRING IS PALINDROM OR NOT?

def is_palindrome(s):
    
    # Convert the string to lowercase and remove spaces for a case-insensitive comparison
    
    s = s.lower().replace(" ", "")
    
    # Compare the string with its reverse
    
    return s == s[::-1]

# Example usage
string = "A man a plan a canal Panama"

if is_palindrome(string):
    
    print(f"'{string}' is a palindrome.")
    
else:
    print(f"'{string}' is not a palindrome.")
    
# USING FOR LOOPS-

    def is_palindrome(s):
        
    # Convert the string to lowercase and remove spaces
    
    s = s.lower().replace(" ", "")
    
    # Check characters from both ends
    for i in range(len(s) // 2):
        if s[i] != s[-(i + 1)]:
            return False
    return True

# Example usage
string = "A man a plan a canal Panama"
if is_palindrome(string):
    print(f"'{string}' is a palindrome.")
else:
    print(f"'{string}' is not a palindrome.")
# Out:
# Object `NOT` not found.
# 'A man a plan a canal Panama' is a palindrome.

# %%
4. write a code to check given two string is anagram of each other

def are_anagrams(str1, str2):
    
    # Remove spaces and convert both strings to lowercase
    str1 = str1.replace(" ", "").lower()
    str2 = str2.replace(" ", "").lower()
    
    # Check if sorted characters of both strings are the same
    return sorted(str1) == sorted(str2)

# Example 
string1 = "listen"
string2 = "silent"

if are_anagrams(string1, string2):
    print(f"'{string1}' and '{string2}' are anagrams.")
else:
    print(f"'{string1}' and '{string2}' are not anagrams.")
    
    
    # without external library-
    
    def are_anagrams(str1, str2):
    # Remove spaces and convert both strings to lowercase
    str1 = str1.replace(" ", "").lower()
    str2 = str2.replace(" ", "").lower()
    
    # If lengths are different, they cannot be anagrams
    
    if len(str1) != len(str2):
        return False
    
    # Create a dictionary to count characters
    char_count = {}
    
    # Count characters in the first string
    for char in str1:
        char_count[char] = char_count.get(char, 0) + 1
    
    # Subtract counts based on the second string
    for char in str2:
        if char in char_count:
            char_count[char] -= 1
        else:
            return False
    
    # If all counts are zero, they are anagrams
    return all(count == 0 for count in char_count.values())

# Example usage
string1 = "listen"
string2 = "silent"

if are_anagrams(string1, string2):
    
    print(f"'{string1}' and '{string2}' are anagrams.")
    
else:
    print(f"'{string1}' and '{string2}' are not anagrams.")

# %%
5.write a code to find all ocurrence of a given substring within another string?


#Using a while loop and str.find()
def find_all_occurrences(s, sub):
    start = 0
    indices = []

    while True:
        start = s.find(sub, start)
        if start == -1:
            break
        indices.append(start)
        start += len(sub)  # Move past the last found substring

    return indices

# Example 
string = "abracadabra"
substring = "abra"

occurrences = find_all_occurrences(string, substring)
print(f"All occurrences of '{substring}' in '{string}':", occurrences)

#Using list comprehension with str.find() and a loop?

def find_all_occurrences(s, sub):
    return [i for i in range(len(s)) if s.startswith(sub, i)]

# Example
string = "abracadabra"
substring = "abra"

occurrences = find_all_occurrences(string, substring)
print(f"All occurrences of '{substring}' in '{string}':", occurrences)

# %%
6.write a code to perform basic string compression using the counts of repeated characters?

def compress_string(s):
    # Initialize the compressed string and the count
    compressed = []
    count = 1

    # Iterate through the string
    for i in range(1, len(s)):
        # If the current character is the same as the previous one, increment the count
        if s[i] == s[i - 1]:
            count += 1
        else:
            # Append the previous character and its count to the compressed string
            compressed.append(s[i - 1] + str(count))
            count = 1  # Reset the count for the new character

    # Append the last character and its count
    compressed.append(s[-1] + str(count))

    # Join the compressed list into a string
    compressed_string = ''.join(compressed)

    # Return the compressed string only if it's shorter than the original string
    return compressed_string if len(compressed_string) < len(s) else s

# Example usage
string = "aabcccccaaa"
compressed_string = compress_string(string)
print(f"Original: {string}")
print(f"Compressed: {compressed_string}")

# %%
7.write a code to determine if a string has all unique characters

def has_unique_characters(s):
    # Create an empty set to store unique characters
    
    char_set = set()

    # Iterate through the string
    for char in s:
        
        # If the character is already in the set, return False
        
        if char in char_set:
            
            return False
        
        # Otherwise, add the character to the set
        
        char_set.add(char)

    # If no duplicates were found, return True
    
    return True

# Example usage
string = "abcdef"
print(f"'{string}' has all unique characters:", has_unique_characters(string))

string = "hello"
print(f"'{string}' has all unique characters:", has_unique_characters(string))

# %%
8.write a code to convert given string to uppercase or lowercase?

# convert to uppercase 
def to_uppercase(s):
    return s.upper()

# Example 
string = "Hello, World!"
uppercase_string = to_uppercase(string)
print(f"Original: {string}")
print(f"Uppercase: {uppercase_string}")

#convert to lowercase

def to_lowercase(s):
    return s.lower()

# Example
string = "Hello, World!"
lowercase_string = to_lowercase(string)
print(f"Original: {string}")
print(f"Lowercase: {lowercase_string}")

# %%
9.write a code to count number of words in a string.

def count_words(s):
    # Split the string into words using whitespace as the delimiter
    words = s.split()
    
    # Return the number of words
    return len(words)

# Example 
string = "Hello, how are you doing today?"
word_count = count_words(string)
print(f"The number of words in the string is: {word_count}")
# Out:
# The number of words in the string is: 6

# %%
10.write a code to concatenate two strings without using + operator?

#using str.join() method

def concatenate_strings(str1, str2):
    
    return ''.join([str1, str2])

# Example 
string1 = "Hello, "
string2 = "World!"
result = concatenate_strings(string1, string2)
print(f"Concatenated String: {result}")

# using f"" string

def concatenate_strings(str1, str2):
    return f"{str1}{str2}"

# Example usage
string1 = "Hello, "
string2 = "World!"
result = concatenate_strings(string1, string2)
print(f"Concatenated String: {result}")

# %%
write a code to remove all occurence of a specific elements from a list?

# using list comprehension

def remove_all_occurrences(lst, element):
    return [item for item in lst if item != element]

# Example 
lst = [1, 2, 3, 4, 2, 2, 5, 6, 2]
element_to_remove = 2
result = remove_all_occurrences(lst, element_to_remove)
print(f"List after removing all occurrences of {element_to_remove}: {result}")


#using filter method

def remove_all_occurrences(lst, element):
    
    return list(filter(lambda x: x != element, lst))

# Example
lst = [1, 2, 3, 4, 2, 2, 5, 6, 2]
element_to_remove = 2
result = remove_all_occurrences(lst, element_to_remove)
print(f"List after removing all occurrences of {element_to_remove}: {result}")


#Using a Loop and remove() method (In-Place Modification)

def remove_all_occurrences(lst, element):
    
    while element in lst:
        
        lst.remove(element)
        
    return lst

# Example usage
lst = [1, 2, 3, 4, 2, 2, 5, 6, 2]
element_to_remove = 2
result = remove_all_occurrences(lst, element_to_remove)
print(f"List after removing all occurrences of {element_to_remove}: {result}")

# %%
12.implement a code to find the second largest number in a given list of integers?


#using sorting
def find_second_largest(numbers):
    if len(numbers) < 2:
        raise ValueError("List must contain at least two elements")

    unique_numbers = list(set(numbers))  # Remove duplicates
    if len(unique_numbers) < 2:
        raise ValueError("Not enough unique elements to find the second largest")

    unique_numbers.sort()
    return unique_numbers[-2]

# Example usage
numbers = [10, 20, 4, 45, 99, 99]
second_largest = find_second_largest(numbers)
print(f"The second largest number is: {second_largest}")

# %%
13.create a code to count the occurence of each element in a list and return a dictionary with elements as a keys and thier counts as values?

def count_occurrences(lst):
    
    counts = {}
    for item in lst:
        if item in counts:
            counts[item] += 1
        else:
            counts[item] = 1
    return counts

# Example usage
lst = [1, 2, 3, 1, 2, 1, 4, 4, 4, 5]
occurrences = count_occurrences(lst)
print("Occurrences:", occurrences)

# %%
14.write a code to reverse a list in-place without using any built-in method


#using two pointer method-

def reverse_list_in_place(lst):
    
    # Initialize two pointers
    
    left = 0
    right = len(lst) - 1
    
    # Swap elements from both ends towards the center
    while left < right:
        # Swap the elements at left and right indices
        lst[left], lst[right] = lst[right], lst[left]
        # Move the pointers towards the center
        left += 1
        right -= 1

# Example usage
my_list = [1, 2, 3, 4, 5]
reverse_list_in_place(my_list)
print("Reversed list:", my_list)

# %%
15.implement a code to find and remove duplicates from a list while preserving the original order of elements

def remove_duplicates(lst):
    
    seen = set()      # To track seen elements
    unique_list = []  # To store unique elements

    for item in lst:
        if item not in seen:
            unique_list.append(item)
            seen.add(item)

    return unique_list

# Example usage
my_list = [1, 2, 3, 2, 4, 5, 1, 6, 4]
result = remove_duplicates(my_list)
print("List after removing duplicates:", result)

# %%
16.create a code to check if a given list is sorted (either in ascending or descending order)or not?

def is_sorted(lst):
    
    if not lst:  # An empty list is considered sorted
        return True

    ascending = True
    descending = True

    # Iterate through the list to check sorting order
    for i in range(len(lst) - 1):
        if lst[i] > lst[i + 1]:
            ascending = False
        if lst[i] < lst[i + 1]:
            descending = False

    return ascending or descending

# Example 
list1 = [1, 2, 3, 4, 5]         # Sorted in ascending order
list2 = [5, 4, 3, 2, 1]         # Sorted in descending order
list3 = [1, 3, 2, 4, 5]         # Not sorted

print(f"List1 is sorted: {is_sorted(list1)}")
print(f"List2 is sorted: {is_sorted(list2)}")
print(f"List3 is sorted: {is_sorted(list3)}")

# %%
17.write a code to merge two sorted lists into a single sorted list?

def merge_sorted_lists(list1, list2):
    merged_list = []
    i, j = 0, 0  # Pointers for list1 and list2

    # Iterate through both lists
    while i < len(list1) and j < len(list2):
        if list1[i] <= list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1

    # If there are remaining elements in list1, append them
    while i < len(list1):
        merged_list.append(list1[i])
        i += 1

    # If there are remaining elements in list2, append them
    while j < len(list2):
        merged_list.append(list2[j])
        j += 1

    return merged_list

# Example 
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
merged = merge_sorted_lists(list1, list2)
print("Merged list:", merged)

# %%
18.implement a code to find the intersection of two given lists?

def intersect_lists(list1, list2):
    
    # Convert lists to sets
    set1 = set(list1)
    set2 = set(list2)
    
    # Find the intersection of the two sets
    intersection = set1 & set2
    
    # Convert the result back to a list if needed
    return list(intersection)

# Example usage
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
intersection = intersect_lists(list1, list2)
print("Intersection:", intersection)

# %%
19. create a code to find the union of two lists without duplicates.

# using set

def union_lists(list1, list2):
    # Convert lists to sets to remove duplicates and perform union
    set1 = set(list1)
    set2 = set(list2)
    
    # Find the union of the two sets
    union = set1 | set2
    
    # Convert the result back to a list if needed
    return list(union)

# Example usage
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
union = union_lists(list1, list2)
print("Union:", union)



# using list comprehension and set

def union_lists(list1, list2):
    seen = set()
    union = []
    
    # Add elements from the first list
    for item in list1:
        if item not in seen:
            union.append(item)
            seen.add(item)
    
    # Add elements from the second list
    for item in list2:
        if item not in seen:
            union.append(item)
            seen.add(item)
    
    return union

# Example usage
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
union = union_lists(list1, list2)
print("Union:", union)

# %%
20. write a code to shuffle a given list randomly without using any built-in shuffle function

#using fisher  yatch or knuth suffle 

import random

def shuffle_list(lst):
    
    # Iterate over the list in reverse order
    
    for i in range(len(lst) - 1, 0, -1):
        
        # Generate a random index from 0 to i
        j = random.randint(0, i)
        
        # Swap the elements at indices i and j
        lst[i], lst[j] = lst[j], lst[i]

# Example usage
my_list = [1, 2, 3, 4, 5]
shuffle_list(my_list)

print("Shuffled list:", my_list)

# %%
21.write a code that takes two tuples as input and returns a new tuple containing elements that are common to both input tuples

def common_elements(tuple1, tuple2):
    # Convert tuples to sets
    set1 = set(tuple1)
    set2 = set(tuple2)
    
    # Find the intersection of the two sets
    common_set = set1 & set2
    
    # Convert the set to a tuple
    common_tuple = tuple(common_set)
    
    return common_tuple

# Example usage
tuple1 = (1, 2, 3, 4, 5)
tuple2 = (4, 5, 6, 7, 8)
common = common_elements(tuple1, tuple2)
print("Common elements:", common)

# %%
22. create a code that prompts the user to enter two sets of integers separated by commas . then print the intersection of these two sets

def get_set_from_input(prompt):
    # Prompt user for input and split the string by commas
    
    user_input = input(prompt)
    
    # Convert the input string to a set of integers
    
    try:
        int_list = [int(item.strip()) for item in user_input.split(',')]
        return set(int_list)
    
    except ValueError:
        print("Invalid input. Please enter only integers separated by commas.")
        return set()

def main():
    
    print("Enter two sets of integers separated by commas.")
    
    # Get the first set from the user
    set1 = get_set_from_input("Enter the first set of integers: ")
    
    # Get the second set from the user
    set2 = get_set_from_input("Enter the second set of integers: ")
    
    # Calculate the intersection of the two sets
    intersection = set1 & set2
    
    # Print the result
    print("Intersection of the two sets:", intersection)

# Run the main function
if __name__ == "__main__":
    main()

# %%
23. write a code to concatenate two tuples.the function should take two tuple as input and return a new tuple containing elements 
from both input tuples 

def concatenate_tuples(tuple1, tuple2):
    
    # Concatenate the two tuples
    result_tuple = tuple1 + tuple2
    
    return result_tuple

# Example 
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

result = concatenate_tuples(tuple1, tuple2)
print("Concatenated tuple:", result)

# %%
24. develop a code that prompts the user to input two sets of strings .then print the elements that are present in the 
first set but not in the second set 

def get_set_from_input(prompt):
    
    # Prompt user for input and split the string by commas
    user_input = input(prompt)
    
    # Convert the input string to a set of strings
    string_set = {item.strip() for item in user_input.split(',')}
    
    return string_set

def main():
    print("Enter two sets of strings separated by commas.")
    
    # Get the first set from the user
    set1 = get_set_from_input("Enter the first set of strings: ")
    
    # Get the second set from the user
    set2 = get_set_from_input("Enter the second set of strings: ")
    
    # Find the difference between the first set and the second set
    difference = set1 - set2
    
    # Print the result
    print("Elements in the first set but not in the second set:", difference)

# Run the main function
if __name__ == "__main__":
    main()

# %%
25. create a code that takes a tuple and two integers as input. the function should return new tuple containing elements 
from the original tuple within the specified range of indices 

def slice_tuple(tpl, start, end):
    
    # Check if the indices are within the valid range
    
    if start < 0 or end > len(tpl) or start > end:
        raise ValueError("Invalid index range")
    
    # Return the slice of the tuple within the specified range
    return tpl[start:end]

# Example 
example_tuple = (10, 20, 30, 40, 50, 60)

start_index = 2

end_index = 5

result = slice_tuple(example_tuple, start_index, end_index)

print("Sliced tuple:", result)

# %%
26 write a code that prompts the user to input two sets of characters.then prints union of these two sets 

def get_set_from_input(prompt):
    
    # Prompt user for input and split the string by commas
    
    user_input = input(prompt)
    
    # Convert the input string to a set of characters
    
    char_set = {char.strip() for char in user_input.split(',')}
    
    return char_set

def main():
    print("Enter two sets of characters separated by commas.")
    
    # Get the first set from the user
    set1 = get_set_from_input("Enter the first set of characters: ")
    
    # Get the second set from the user
    set2 = get_set_from_input("Enter the second set of characters: ")
    
    # Find the union of the two sets
    union = set1 | set2
    
    # Print the result
    print("Union of the two sets:", union)

# Run the main function
if __name__ == "__main__":
    main()

# %%
27 develop a code that takes a tuple of integers as input .the function should return the maximum and minimum values from 
the tuples using tuples unpacking.

def find_max_min(tpl):
    
    # Find the maximum and minimum values in the tuple
    
    max_value = max(tpl)
    min_value = min(tpl)
    
    # Return the max and min as a tuple using tuple unpacking
    
    return max_value, min_value

# Example usage
example_tuple = (23, 1, 45, 78, 2, 89, 6)

max_val, min_val = find_max_min(example_tuple)

print("Maximum value:", max_val)
print("Minimum value:", min_val)

# %%
28.create a code that defines two sets of integers. then print the union,intersection and difference of these two sets

# Define two sets of integers

set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Union of the two sets
union_set = set1.union(set2)

print("Union:", union_set)

# Intersection of the two sets
intersection_set = set1.intersection(set2)

print("Intersection:", intersection_set)

# Difference of the two sets (set1 - set2)
difference_set = set1.difference(set2)

print("Difference (set1 - set2):", difference_set)

# Difference of the two sets (set2 - set1)
difference_set2 = set2.difference(set1)

print("Difference (set2 - set1):", difference_set2)

# %%
29.write a code that takes a tuple and an element as input . the function should return the count of occurences of the given element in tuple

def count_occurrences(tpl, element):
    
    # Use the count() method to count the occurrences of the element in the tuple
   
    return tpl.count(element)

# Example usage
example_tuple = (1, 2, 3, 4, 2, 2, 5, 2)
element_to_count = 2

occurrences = count_occurrences(example_tuple, element_to_count)

print(f"The element {element_to_count} occurs {occurrences} times in the tuple.")

# %%
30.Develop a code that prompts the user to input two sets of strings. Then, print the symmetric difference of these two sets.

def get_set_from_input(prompt):
    
    # Prompt user for input and split the string by commas
    user_input = input(prompt)
    
    # Convert the input string to a set of strings
    string_set = {item.strip() for item in user_input.split(',')}
    
    return string_set

def main():
    
    print("Enter two sets of strings separated by commas.")
    
    # Get the first set from the user
    set1 = get_set_from_input("Enter the first set of strings: ")
    
    # Get the second set from the user
    set2 = get_set_from_input("Enter the second set of strings: ")
    
    # Find the symmetric difference of the two sets
    symmetric_difference = set1 ^ set2
    
    # Print the result
    print("Symmetric difference of the two sets:", symmetric_difference)

# Run the main function
if __name__ == "__main__":
    main()

# %%
31.Write a code that takes a list of words as input and returns a dictionary where the keys are unique words and 
the values are the frequencies of those words in the input list.

def count_word_frequencies(word_list):
    # Create an empty dictionary to store word frequencies
    
    word_freq = {}
    
    # Iterate over each word in the list
    for word in word_list:
        
        # If the word is already a key in the dictionary, increment its value
        if word in word_freq:
            word_freq[word] += 1
            
        # Otherwise, add the word as a key with a value of 1
        else:
            word_freq[word] = 1
    
    return word_freq

# Example usage
words = ["apple", "banana", "apple", "orange", "banana", "apple"]

word_frequencies = count_word_frequencies(words)

print("Word frequencies:", word_frequencies)

# %%
32.Write a code that takes two dictionaries as input and merges them into a single dictionary. If there are common keys, 
the values should be added together.


def merge_dictionaries(dict1, dict2):
    # Create a new dictionary to store the merged result
    merged_dict = dict1.copy()
    
    # Iterate through the second dictionary
    for key, value in dict2.items():
        # If the key is already in the merged dictionary, add the values
        if key in merged_dict:
            merged_dict[key] += value
        # If the key is not in the merged dictionary, add the key-value pair
        else:
            merged_dict[key] = value
    
    return merged_dict

# Example usage
dict1 = {'apple': 5, 'banana': 3, 'orange': 2}
dict2 = {'banana': 2, 'orange': 4, 'grape': 7}

merged_result = merge_dictionaries(dict1, dict2)
print("Merged dictionary:", merged_result)

# %%
33.Write a code to access a value in a nested dictionary. The function should take the dictionary and a list of keys as input,
and return the corresponding value. If any of the keys do not exist in the dictionary ,the function should return None.


def get_nested_value(nested_dict, keys_list):
    current_value = nested_dict
    
    for key in keys_list:
        # Check if the key exists at the current level of the dictionary
        
        if key in current_value:
            current_value = current_value[key]
            
        else:
            return None  # Return None if the key is not found
        
    return current_value

# Example usage
nested_dict = {
    'a': {
        'b': {
            'c': 42
        }
    },
    'x': {
        'y': {
            'z': 99
        }
    }
}

keys_list = ['a', 'b', 'c']
result = get_nested_value(nested_dict, keys_list)

print("The value for the keys", keys_list, "is:", result)

# Another example with a missing key

keys_list = ['x', 'y', 'not_here']
result = get_nested_value(nested_dict, keys_list)

print("The value for the keys", keys_list, "is:", result)

# %%
34.Write a code that takes a dictionary as input and returns a sorted version of it based on the values. 
You can choose whether to sort in ascending or descending order


def sort_dict_by_values(input_dict, ascending=True):
    
    # Sort the dictionary by values
    sorted_dict = dict(sorted(input_dict.items(), key=lambda item: item[1], reverse=not ascending))
    
    return sorted_dict

# Example usage
example_dict = {'apple': 5, 'banana': 2, 'orange': 8, 'grape': 3}

# Sort in ascending order

sorted_dict_ascending = sort_dict_by_values(example_dict, ascending=True)
print("Sorted dictionary (ascending):", sorted_dict_ascending)

# Sort in descending order

sorted_dict_descending = sort_dict_by_values(example_dict, ascending=False)

print("Sorted dictionary (descending):", sorted_dict_descending)

# %%
35.Write a code that inverts a dictionary, swapping keys and values. Ensure that the inverted dictionary correctly handles cases where 
multiple keys have the same value by storing the keys as a list in the inverted dictionary.

def invert_dictionary(input_dict):
    inverted_dict = {}
    
    for key, value in input_dict.items():
        
        # If the value is already a key in the inverted dictionary, append the current key to the list
        
        if value in inverted_dict:
            inverted_dict[value].append(key)
            
        # Otherwise, create a new list with the current key as the first element
        
        else:
            inverted_dict[value] = [key]
    
    return inverted_dict

# Example usage
example_dict = {'apple': 1, 'banana': 2, 'orange': 1, 'grape': 3, 'pear': 2}

inverted_dict = invert_dictionary(example_dict)

print("Inverted dictionary:", inverted_dict)
